# %%
import svm

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Choose which data to classify:
DATASET_PATH = '../data/'
filename = DATASET_PATH + 'classification-xor.csv' # could be classification-simple.csv' or'classification-xor.csv'

# %%
# Set the hyperparameters of the SVM
C = 10.0
kernel = 'linear'
gamma = 10.0

# %%
# Initialize the SVM class
model = svm.SVM(filename, C, kernel, gamma)
# Out:
# Original data length was 1000
# After dropping rows with nan in any label column, length is 1000
# 599 rows in training data
# 195 rows in validation data
# 206 rows in testing data

# %%
# Look at the data you are trying to classify
model.plot_binary_classification_data()

# %%
model.train()

# %%
# See the accuracy you got on the validation set. 
# You can try changing the parameters of your model 
# to improve the validation accuracy.
acc, auc = model.test_on_validation()
# Out:
# Final results on validation data: 0.446153846154 accuracy 0.552362707535 AUC

# %%
# Look at the decision boundary learned by your model.
model.plot_binary_classification_data(with_decision_boundary=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-c9229c7b7351> in <module>()
#       1 # Look at the decision boundary learned by your model.
# ----> 2 model.plot_binary_classification_data(with_decision_boundary=True)
#
# /Users/natasha/Developer/PersonalizedMachineLearning/recitation/svm.py in plot_binary_classification_data(self, with_decision_boundary)
#     167             # Use matplotlib contour function to show decision boundary on mesh
#     168             Z = Z.reshape(xx1.shape)
# --> 169             plt.contour(xx1, xx2, Z, cmap=plt.cm.Paired)
#     170
#     171         plt.show()
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/pyplot.pyc in contour(*args, **kwargs)
#    2630         ax.hold(hold)
#    2631     try:
# -> 2632         ret = ax.contour(*args, **kwargs)
#    2633         draw_if_interactive()
#    2634     finally:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axes.pyc in contour(self, *args, **kwargs)
#    7974             self.cla()
#    7975         kwargs['filled'] = False
# -> 7976         return mcontour.QuadContourSet(self, *args, **kwargs)
#    7977     contour.__doc__ = mcontour.QuadContourSet.contour_doc
#    7978
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#    1412         are described in QuadContourSet.contour_doc.
#    1413         """
# -> 1414         ContourSet.__init__(self, ax, *args, **kwargs)
#    1415
#    1416     def _process_args(self, *args, **kwargs):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#     859
#     860         self._process_args(*args, **kwargs)
# --> 861         self._process_levels()
#     862
#     863         if self.colors is not None:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/contour.pyc in _process_levels(self)
#    1190         # The following attributes are no longer needed, and
#    1191         # should be deprecated and removed to reduce confusion.
# -> 1192         self.vmin = np.amin(self.levels)
#    1193         self.vmax = np.amax(self.levels)
#    1194
#
# /Library/Python/2.7/site-packages/numpy/core/fromnumeric.pyc in amin(a, axis, out, keepdims)
#    2350
#    2351     return _methods._amin(a, axis=axis,
# -> 2352                           out=out, **kwargs)
#    2353
#    2354
#
# /Library/Python/2.7/site-packages/numpy/core/_methods.pyc in _amin(a, axis, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
# ---> 29     return umr_minimum(a, axis, None, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
x1_min = model.data_loader.train_X[:, 0].min() - 1
x1_max = model.data_loader.train_X[:, 0].max() + 1
x2_min = model.data_loader.train_X[:, 1].min() - 1
x2_max = model.data_loader.train_X[:, 1].max() + 1
xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, 0.1),
                       np.arange(x2_min, x2_max, 0.1))

# Make predictions for each point in the mesh
Z = model.predict(np.c_[xx1.ravel(), xx2.ravel()])

# %%
np.sZ
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Try comparing the following parameter settings. What happens to the decision boundary?
# C = 100.0, gamma = .01
# C = 1000.0, gamma = 1.0
# C = 1000.0, gamma = 100.0
