# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import sys

import neural_net
import data_funcs

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
DATASET_PATH = './data/'

# %% [markdown]
# ## Classification - simple dataset

# %%
# Set the hyperparameters
layer_sizes = [128,32]
batch_size = 25
learning_rate = .0001
dropout_prob = 0.5
weight_penalty = 0.01
clip_gradients = True

# %%
# If you make changes to the .py files, you will need to reload them before
# the jupyter notebook can see the changes. 
reload(neural_net)
neural_net.reload_files()

# %%
# Initialize the neural network class with the settings and hyperparameters
net = neural_net.NeuralNetwork(DATASET_PATH + 'classification-simple.csv', 'simple_classifier', 
                               layer_sizes, batch_size, learning_rate, dropout_prob, 
                               weight_penalty, clip_gradients)
# Out:
# Original data length was 1000
# After dropping rows with nan in any label column, length is 1000
# 583 rows in training data
# 230 rows in validation data
# 187 rows in testing data
#
# Performing classification.
# Input dimensions (number of features): 2
# Number of classes/outputs: 2
#
# Building computation graph...
# Okay, making a neural net with the following structure:
# [('2x128', '128'), ('128x32', '32'), ('32x2', '2')]

# %%
net.plot_binary_classification_data()

# %%
# Perform SGD
net.train(num_steps=200)
# Out:
# Training iteration 0
# 	 Training accuracy 0.52
# 	 Validation accuracy 0.613043
# Training iteration 10
# 	 Training accuracy 0.64
# 	 Validation accuracy 0.773913
# Training iteration 20
# 	 Training accuracy 0.52
# 	 Validation accuracy 0.973913
# Training iteration 30
# 	 Training accuracy 0.68
# 	 Validation accuracy 0.982609
# Training iteration 40
# 	 Training accuracy 0.76
# 	 Validation accuracy 0.991304
# Training iteration 50
# 	 Training accuracy 0.72
# 	 Validation accuracy 0.991304
# Training iteration 60
# 	 Training accuracy 0.72
# 	 Validation accuracy 0.991304
# Training iteration 70
# 	 Training accuracy 0.92
# 	 Validation accuracy 0.991304
# Training iteration 80
# 	 Training accuracy 0.76
# 	 Validation accuracy 0.995652
# Training iteration 90
# 	 Training accuracy 0.72
# 	 Validation accuracy 0.995652
# Training iteration 100
# 	 Training accuracy 0.8
# 	 Validation accuracy 0.995652
# Training iteration 110
# 	 Training accuracy 0.92
# 	 Validation accuracy 0.995652
# Training iteration 120
# 	 Training accuracy 0.96
# 	 Validation accuracy 0.995652
# Training iteration 130
# 	 Training accuracy 0.96
# 	 Validation accuracy 0.995652
# Training iteration 140
# 	 Training accuracy 0.96
# 	 Validation accuracy 0.995652
# Training iteration 150
# 	 Training accuracy 0.96
# 	 Validation accuracy 0.995652
# Training iteration 160
# 	 Training accuracy 0.92
# 	 Validation accuracy 0.995652
# Training iteration 170
# 	 Training accuracy 1.0
# 	 Validation accuracy 0.995652
# Training iteration 180
# 	 Training accuracy 0.88
# 	 Validation accuracy 0.995652
# Training iteration 190
# 	 Training accuracy 1.0
# 	 Validation accuracy 0.995652

# %%
net.plot_training_progress()

# %%
# See the decision boundary learned by the neural network
net.plot_binary_classification_data(with_decision_boundary=True)

# %%
net.test_on_validation()
# Out:
# Final accuracy on validation data is: 0.995652
# 0.9956522

# %%
# To see the tensorflow model you've built in tensorboard, run the following
journalist = tf.summary.FileWriter(net.checkpoint_dir, graph=net.session.graph)
journalist.flush()

# Now enter the following command at the command line
# > tensorboard --logdir 'saved_models'
# (you may need to replace 'saved_models' with the path to the actual 
# net.checkpoint_dir you are using)

# %% [markdown]
# ## Classification - XOR dataset

# %%
# Set the hyperparameters
layer_sizes = [512,128,32]
batch_size = 25
learning_rate = .001
dropout_prob = 0.5
weight_penalty = 0.01
clip_gradients = True

# %%
reload(neural_net)
neural_net.reload_files()

# %%
net = neural_net.NeuralNetwork(DATASET_PATH + 'classification-xor.csv', 'xor_classifier', 
                               layer_sizes, batch_size, learning_rate, dropout_prob, 
                               weight_penalty, clip_gradients)
# Out:
# Original data length was 1000
# After dropping rows with nan in any label column, length is 1000
# 599 rows in training data
# 195 rows in validation data
# 206 rows in testing data
#
# Performing classification.
# Input dimensions (number of features): 2
# Number of classes/outputs: 2
#
# Building computation graph...
# Okay, making a neural net with the following structure:
# [('2x512', '512'), ('512x128', '128'), ('128x32', '32'), ('32x2', '2')]

# %%
net.plot_binary_classification_data()

# %%
net.train(num_steps=200)
# Out:
# Training iteration 0
# 	 Training accuracy 0.8
# 	 Validation accuracy 0.502564
# Training iteration 10
# 	 Training accuracy 0.84
# 	 Validation accuracy 0.85641
# Training iteration 20
# 	 Training accuracy 0.8
# 	 Validation accuracy 0.933333
# Training iteration 30
# 	 Training accuracy 0.76
# 	 Validation accuracy 0.928205
# Training iteration 40
# 	 Training accuracy 0.88
# 	 Validation accuracy 0.933333
# Training iteration 50
# 	 Training accuracy 0.96
# 	 Validation accuracy 0.928205
# Training iteration 60
# 	 Training accuracy 0.96
# 	 Validation accuracy 0.933333
# Training iteration 70
# 	 Training accuracy 0.96
# 	 Validation accuracy 0.938462
# Training iteration 80
# 	 Training accuracy 0.88
# 	 Validation accuracy 0.933333
# Training iteration 90
# 	 Training accuracy 0.96
# 	 Validation accuracy 0.928205
# Training iteration 100
# 	 Training accuracy 0.96
# 	 Validation accuracy 0.928205
# Training iteration 110
# 	 Training accuracy 0.92
# 	 Validation accuracy 0.938462
# Training iteration 120
# 	 Training accuracy 0.96
# 	 Validation accuracy 0.938462
# Training iteration 130
# 	 Training accuracy 1.0
# 	 Validation accuracy 0.94359
# Training iteration 140
# 	 Training accuracy 0.96
# 	 Validation accuracy 0.94359
# Training iteration 150
# 	 Training accuracy 0.92
# 	 Validation accuracy 0.938462
# Training iteration 160
# 	 Training accuracy 0.92
# 	 Validation accuracy 0.933333
# Training iteration 170
# 	 Training accuracy 0.92
# 	 Validation accuracy 0.94359
# Training iteration 180
# 	 Training accuracy 0.88
# 	 Validation accuracy 0.938462
# Training iteration 190
# 	 Training accuracy 0.96
# 	 Validation accuracy 0.938462

# %%
net.plot_training_progress()

# %%
net.plot_binary_classification_data(with_decision_boundary=True)

# %% [markdown]
# ## Regression - sin wave

# %%
# Set the hyperparameters
layer_sizes = [128,32]
batch_size = 25
learning_rate = .001
dropout_prob = 1.0
weight_penalty = 0.0
clip_gradients = True

# %%
reload(neural_net)
neural_net.reload_files()

# %%
net = neural_net.NeuralNetwork(DATASET_PATH + 'regression-sin.csv', 'sin_regressor', 
                               layer_sizes, batch_size, learning_rate, dropout_prob, 
                               weight_penalty, clip_gradients, output_type='regression')
# Out:
# Original data length was 500
# After dropping rows with nan in any label column, length is 500
# 308 rows in training data
# 96 rows in validation data
# 96 rows in testing data
#
# Performing regression.
# Input dimensions (number of features): 1
# Number of classes/outputs: 1
#
# Building computation graph...
# Okay, making a neural net with the following structure:
# [('1x128', '128'), ('128x32', '32'), ('32x1', '1')]

# %%
net.plot_regression_data()

# %%
net.train(num_steps=3000, output_every_nth=300)
# Out:
# Training iteration 0
# 	 Training RMSE 0.52374767112
# 	 Validation RMSE 0.643597365625
# Training iteration 300
# 	 Training RMSE 0.0604285689345
# 	 Validation RMSE 0.0865399395169
# Training iteration 600
# 	 Training RMSE 0.0893740368299
# 	 Validation RMSE 0.0619811514022
# Training iteration 900
# 	 Training RMSE 0.108265866118
# 	 Validation RMSE 0.0561079771759
# Training iteration 1200
# 	 Training RMSE 0.0483595450236
# 	 Validation RMSE 0.0612061522009
# Training iteration 1500
# 	 Training RMSE 0.0518859874387
# 	 Validation RMSE 0.0507066786901
# Training iteration 1800
# 	 Training RMSE 0.105049856989
# 	 Validation RMSE 0.0616218468644
# Training iteration 2100
# 	 Training RMSE 0.0675619314408
# 	 Validation RMSE 0.0620747669023
# Training iteration 2400
# 	 Training RMSE 0.103771639397
# 	 Validation RMSE 0.0771409862942
# Training iteration 2700
# 	 Training RMSE 0.04980485712
# 	 Validation RMSE 0.0566778751205

# %%
net.plot_training_progress()

# %%
net.plot_regression_data(with_decision_boundary=True)

# %%
net.test_on_validation()
# Out:
# Final RMSE on validation data is: 0.06848075628
# 0.068480756279963875

# %% [markdown]
# ## Regression - step function

# %%
# Set the hyperparameters
layer_sizes = [128,64,32]
batch_size = 25
learning_rate = .001
dropout_prob = 1.0
weight_penalty = 0.0
clip_gradients = True

# %%
reload(neural_net)
neural_net.reload_files()

# %%
net = neural_net.NeuralNetwork(DATASET_PATH + 'regression-step.csv', 'step_regressor', 
                               layer_sizes, batch_size, learning_rate, dropout_prob, 
                               weight_penalty, clip_gradients, output_type='regression')
# Out:
# Original data length was 500
# After dropping rows with nan in any label column, length is 500
# 314 rows in training data
# 86 rows in validation data
# 100 rows in testing data
#
# Performing regression.
# Input dimensions (number of features): 1
# Number of classes/outputs: 1
#
# Building computation graph...
# Okay, making a neural net with the following structure:
# [('1x128', '128'), ('128x64', '64'), ('64x32', '32'), ('32x1', '1')]

# %%
net.plot_regression_data()

# %%
net.train(num_steps=3500, output_every_nth=100)
# Out:
# Training iteration 0
# 	 Training RMSE 0.586862507086
# 	 Validation RMSE 0.663215459364
# Training iteration 100
# 	 Training RMSE 0.304551999356
# 	 Validation RMSE 0.225313879986
# Training iteration 200
# 	 Training RMSE 0.164534360487
# 	 Validation RMSE 0.188551749438
# Training iteration 300
# 	 Training RMSE 0.213691404954
# 	 Validation RMSE 0.169879005657
# Training iteration 400
# 	 Training RMSE 0.21643840736
# 	 Validation RMSE 0.152604842155
# Training iteration 500
# 	 Training RMSE 0.112518117025
# 	 Validation RMSE 0.124096688337
# Training iteration 600
# 	 Training RMSE 0.26458584883
# 	 Validation RMSE 0.114669211376
# Training iteration 700
# 	 Training RMSE 0.226705882196
# 	 Validation RMSE 0.143332449789
# Training iteration 800
# 	 Training RMSE 0.116947815174
# 	 Validation RMSE 0.10711634603
# Training iteration 900
# 	 Training RMSE 0.16679434359
# 	 Validation RMSE 0.108287264533
# Training iteration 1000
# 	 Training RMSE 0.167059921233
# 	 Validation RMSE 0.0941653079462
# Training iteration 1100
# 	 Training RMSE 0.107853918184
# 	 Validation RMSE 0.120169374836
# Training iteration 1200
# 	 Training RMSE 0.12027098816
# 	 Validation RMSE 0.0772188327966
# Training iteration 1300
# 	 Training RMSE 0.0917055282173
# 	 Validation RMSE 0.0893733860594
# Training iteration 1400
# 	 Training RMSE 0.124964265896
# 	 Validation RMSE 0.0754397937013
# Training iteration 1500
# 	 Training RMSE 0.160554741501
# 	 Validation RMSE 0.0845238110958
# Training iteration 1600
# 	 Training RMSE 0.207128791632
# 	 Validation RMSE 0.0782553784899
# Training iteration 1700
# 	 Training RMSE 0.168949699341
# 	 Validation RMSE 0.0547995518604
# Training iteration 1800
# 	 Training RMSE 0.0398659906847
# 	 Validation RMSE 0.0812294160528
# Training iteration 1900
# 	 Training RMSE 0.0593808318587
# 	 Validation RMSE 0.0981834373664
# Training iteration 2000
# 	 Training RMSE 0.179172908519
# 	 Validation RMSE 0.0696769108279
# Training iteration 2100
# 	 Training RMSE 0.021487122016
# 	 Validation RMSE 0.0895209616171
# Training iteration 2200
# 	 Training RMSE 0.0780564759559
# 	 Validation RMSE 0.051509262903
# Training iteration 2300
# 	 Training RMSE 0.218859884421
# 	 Validation RMSE 0.0728794290766
# Training iteration 2400
# 	 Training RMSE 0.110700049574
# 	 Validation RMSE 0.0945844697761
# Training iteration 2500
# 	 Training RMSE 0.107667429124
# 	 Validation RMSE 0.0869869928954
# Training iteration 2600
# 	 Training RMSE 0.127234561982
# 	 Validation RMSE 0.1176195558
# Training iteration 2700
# 	 Training RMSE 0.0252725226764
# 	 Validation RMSE 0.124662429657
# Training iteration 2800
# 	 Training RMSE 0.0125190055259
# 	 Validation RMSE 0.0931270641531
# Training iteration 2900
# 	 Training RMSE 0.112082889986
# 	 Validation RMSE 0.0836942848537
# Training iteration 3000
# 	 Training RMSE 0.0548727272906
# 	 Validation RMSE 0.0775282430671
# Training iteration 3100
# 	 Training RMSE 0.198831047767
# 	 Validation RMSE 0.063584637469
# Training iteration 3200
# 	 Training RMSE 0.0379557371825
# 	 Validation RMSE 0.103858338552
# Training iteration 3300
# 	 Training RMSE 0.140243788259
# 	 Validation RMSE 0.0859551642845
# Training iteration 3400
# 	 Training RMSE 0.142324890369
# 	 Validation RMSE 0.107732267585

# %%
net.plot_training_progress()

# %%
net.plot_regression_data(with_decision_boundary=True)
